# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/transactions_data.csv")

print(f"Satır sayısı : {len(df):,}")
print(f"Kolon sayısı : {len(df.columns)}")
print(f"Kolonlar     : {list(df.columns)}")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       4 df = pd.read_csv("../data/transactions_data.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import subprocess
subprocess.run(["pip", "install", "pandas", "numpy"])
# Out:
# CompletedProcess(args=['pip', 'install', 'pandas', 'numpy'], returncode=1)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/transactions_data.csv")

print(f"Satır sayısı : {len(df):,}")
print(f"Kolon sayısı : {len(df.columns)}")
print(f"Kolonlar     : {list(df.columns)}")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       4 df = pd.read_csv("../data/transactions_data.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
subprocess.run([sys.executable, "-m", "pip", "install", "pandas", "numpy"])
# Out:
# CompletedProcess(args=['c:\\financeai\\venv\\Scripts\\python.exe', '-m', 'pip', 'install', 'pandas', 'numpy'], returncode=0)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/transactions_data.csv")

print(f"Satır sayısı : {len(df):,}")
print(f"Kolon sayısı : {len(df.columns)}")
print(f"Kolonlar     : {list(df.columns)}")
df.head()
# Out:
# Satır sayısı : 13,305,915
# Kolon sayısı : 12
# Kolonlar     : ['id', 'date', 'client_id', 'card_id', 'amount', 'use_chip', 'merchant_id', 'merchant_city', 'merchant_state', 'zip', 'mcc', 'errors']
#         id                 date  client_id  card_id   amount  \
# 0  7475327  2010-01-01 00:01:00       1556     2972  $-77.00
# 1  7475328  2010-01-01 00:02:00        561     4575   $14.57
# 2  7475329  2010-01-01 00:02:00       1129      102   $80.00
# 3  7475331  2010-01-01 00:05:00        430     2860  $200.00
# 4  7475332  2010-01-01 00:06:00        848     3915   $46.41
#
#             use_chip  merchant_id merchant_city merchant_state      zip   mcc  \
# 0  Swipe Transaction        59935        Beulah             ND  58523.0  5499
# 1  Swipe Transaction        67570    Bettendorf             IA  52722.0  5311
# 2  Swipe Transaction        27092         Vista             CA  92084.0  4829
# 3  Swipe Transaction        27092   Crown Point             IN  46307.0  4829
# ...

# %%
print(df.dtypes)
print(df.isnull().sum())
df.describe()
# Out:
# id                  int64
# date                  str
# client_id           int64
# card_id             int64
# amount                str
# use_chip              str
# merchant_id         int64
# merchant_city         str
# merchant_state        str
# zip               float64
# mcc                 int64
# errors                str
# dtype: object
# id                       0
# date                     0
# client_id                0
# card_id                  0
# amount                   0
# use_chip                 0
# merchant_id              0
# merchant_city            0
# merchant_state     1563700
# zip                1652706
# mcc                      0
# errors            13094522
# dtype: int64
#                  id     client_id       card_id   merchant_id           zip  \
# count  1.330592e+07  1.330592e+07  1.330592e+07  1.330592e+07  1.165321e+07
# mean   1.558402e+07  1.026812e+03  3.475268e+03  4.772376e+04  5.132782e+04
# ...

# %%
df['amount'] = df['amount'].replace('[\$,]', '', regex=True).astype(float)
df['date'] = pd.to_datetime(df['date'])
df['errors'] = df['errors'].fillna('No Error')
df['merchant_state'] = df['merchant_state'].fillna('Unknown')
df['zip'] = df['zip'].fillna(0).astype(int).astype(str)
df['zip'] = df['zip'].replace('0', 'Unknown')
df = df.drop_duplicates()
print(f"Temiz satır sayısı: {len(df):,}")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Ebra Nur Sayar\AppData\Local\Temp\ipykernel_15172\1797440570.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df['amount'] = df['amount'].replace('[\$,]', '', regex=True).astype(float)
# Temiz satır sayısı: 13,305,915

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['hour'] = df['date'].dt.hour
df['is_weekend'] = df['date'].dt.dayofweek.isin([5,6]).astype(int)
df['transaction_type'] = df['amount'].apply(lambda x: 'Gelir' if x > 0 else 'Gider')
df['abs_amount'] = df['amount'].abs()
df.head()
# Out:
#         id                date  client_id  card_id  amount           use_chip  \
# 0  7475327 2010-01-01 00:01:00       1556     2972  -77.00  Swipe Transaction
# 1  7475328 2010-01-01 00:02:00        561     4575   14.57  Swipe Transaction
# 2  7475329 2010-01-01 00:02:00       1129      102   80.00  Swipe Transaction
# 3  7475331 2010-01-01 00:05:00        430     2860  200.00  Swipe Transaction
# 4  7475332 2010-01-01 00:06:00        848     3915   46.41  Swipe Transaction
#
#    merchant_id merchant_city merchant_state    zip   mcc    errors  year  \
# 0        59935        Beulah             ND  58523  5499  No Error  2010
# 1        67570    Bettendorf             IA  52722  5311  No Error  2010
# 2        27092         Vista             CA  92084  4829  No Error  2010
# 3        27092   Crown Point             IN  46307  4829  No Error  2010
# 4        13051       Harwood             MD  20776  5813  No Error  2010
#
#    month  hour  is_weekend transaction_type  abs_amount
# ...

# %%
import json
with open('../data/mcc_codes.json', 'r') as f:
    mcc_dict = json.load(f)

df['mcc_str'] = df['mcc'].astype(str)
df['kategori'] = df['mcc_str'].map(mcc_dict).fillna('Diğer')
print(df['kategori'].value_counts().head(15))
# Out:
# kategori
# Grocery Stores, Supermarkets                  1592584
# Miscellaneous Food Stores                     1460875
# Service Stations                              1424711
# Eating Places and Restaurants                  999738
# Drug Stores and Pharmacies                     772913
# Tolls and Bridge Fees                          674135
# Wholesale Clubs                                601942
# Money Transfer                                 589140
# Taxicabs and Limousines                        500662
# Fast Food Restaurants                          499659
# Automotive Service Shops                       478263
# Department Stores                              475384
# Drinking Places (Alcoholic Beverages)          248570
# Discount Stores                                246545
# Utilities - Electric, Gas, Water, Sanitary     242993
# Name: count, dtype: int64

# %%
df.to_parquet('../data/transactions_clean.parquet', index=False)
print("✅ Kaydedildi!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.to_parquet('../data/transactions_clean.parquet', index=False)
#       2 print("✅ Kaydedildi!")
#
# File c:\financeai\venv\Lib\site-packages\pandas\core\frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)   3131 >>> content = f.read()
#    3132 """
#    3133 from pandas.io.parquet import to_parquet
# -> 3135 return to_parquet(
#    3136     self,
#    3137     path,
#    3138     engine,
#    3139     compression=compression,
#    3140     index=index,
#    3141     partition_cols=partition_cols,
#    3142     storage_options=storage_options,
#    3143     filesystem=filesystem,
#    3144     **kwargs,
#    3145 )
#
# ...

# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "pyarrow", "--break-system-packages"])
# Out:
# CompletedProcess(args=['c:\\financeai\\venv\\Scripts\\python.exe', '-m', 'pip', 'install', 'pyarrow', '--break-system-packages'], returncode=0)

# %%
df.to_csv('../data/transactions_clean.csv', index=False)
print("✅ Kaydedildi!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv('../data/transactions_clean.csv', index=False)
#       2 print("✅ Kaydedildi!")
#
# NameError: name 'df' is not defined

# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "pandas", "numpy", "pyarrow"])

import pandas as pd
import numpy as np
import json

# Veri yükle
df = pd.read_csv("../data/transactions_data.csv")
print(f"Yüklendi: {len(df):,} satır")

# Temizle
df['amount'] = df['amount'].replace('[\$,]', '', regex=True).astype(float)
df['date'] = pd.to_datetime(df['date'])
df['errors'] = df['errors'].fillna('No Error')
df['merchant_state'] = df['merchant_state'].fillna('Unknown')
df['zip'] = df['zip'].fillna(0).astype(int).astype(str)
df['zip'] = df['zip'].replace('0', 'Unknown')
df = df.drop_duplicates()
print(f"Temizlendi: {len(df):,} satır")

# Yeni kolonlar
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['hour'] = df['date'].dt.hour
df['is_weekend'] = df['date'].dt.dayofweek.isin([5,6]).astype(int)
df['transaction_type'] = df['amount'].apply(lambda x: 'Gelir' if x > 0 else 'Gider')
df['abs_amount'] = df['amount'].abs()

# MCC kategorileri
with open('../data/mcc_codes.json', 'r') as f:
    mcc_dict = json.load(f)

df['mcc_str'] = df['mcc'].astype(str)
df['kategori'] = df['mcc_str'].map(mcc_dict).fillna('Diğer')
print(f"Kategoriler eklendi")

# Kaydet
try:
    df.to_parquet('../data/transactions_clean.parquet', index=False)
    print("✅ Parquet olarak kaydedildi!")
except:
    df.to_csv('../data/transactions_clean.csv', index=False)
    print("✅ CSV olarak kaydedildi!")

df.head()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\$'
# <>:13: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Ebra Nur Sayar\AppData\Local\Temp\ipykernel_3876\3842564577.py:13: SyntaxWarning: invalid escape sequence '\$'
#   df['amount'] = df['amount'].replace('[\$,]', '', regex=True).astype(float)
# Yüklendi: 13,305,915 satır
# Temizlendi: 13,305,915 satır
# Kategoriler eklendi
# C:\Users\Ebra Nur Sayar\AppData\Local\Temp\ipykernel_3876\3842564577.py:13: SyntaxWarning: invalid escape sequence '\$'
#   df['amount'] = df['amount'].replace('[\$,]', '', regex=True).astype(float)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 40
#      39 try:
# ---> 40     df.to_parquet('../data/transactions_clean.parquet', index=False)
#      41     print("✅ Parquet olarak kaydedildi!")
#
# ...

# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "pandas", "numpy", "pyarrow"])

import pandas as pd
import numpy as np
import json

# Veri yükle
df = pd.read_csv("../data/transactions_data.csv")
print(f"Yüklendi: {len(df):,} satır")

# Temizle
df['amount'] = df['amount'].replace('[\$,]', '', regex=True).astype(float)
df['date'] = pd.to_datetime(df['date'])
df['errors'] = df['errors'].fillna('No Error')
df['merchant_state'] = df['merchant_state'].fillna('Unknown')
df['zip'] = df['zip'].fillna(0).astype(int).astype(str)
df['zip'] = df['zip'].replace('0', 'Unknown')
df = df.drop_duplicates()
print(f"Temizlendi: {len(df):,} satır")

# Yeni kolonlar
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['hour'] = df['date'].dt.hour
df['is_weekend'] = df['date'].dt.dayofweek.isin([5,6]).astype(int)
df['transaction_type'] = df['amount'].apply(lambda x: 'Gelir' if x > 0 else 'Gider')
df['abs_amount'] = df['amount'].abs()

# MCC kategorileri
with open('../data/mcc_codes.json', 'r') as f:
    mcc_dict = json.load(f)

df['mcc_str'] = df['mcc'].astype(str)
df['kategori'] = df['mcc_str'].map(mcc_dict).fillna('Diğer')
print(f"Kategoriler eklendi")

# Kaydet
try:
    df.to_parquet('../data/transactions_clean.parquet', index=False)
    print("✅ Parquet olarak kaydedildi!")
except:
    df.to_csv('../data/transactions_clean.csv', index=False)
    print("✅ CSV olarak kaydedildi!")

df.head()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\$'
# <>:13: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Ebra Nur Sayar\AppData\Local\Temp\ipykernel_3876\2318163944.py:13: SyntaxWarning: invalid escape sequence '\$'
#   df['amount'] = df['amount'].replace('[\$,]', '', regex=True).astype(float)
# Yüklendi: 13,305,915 satır
# Temizlendi: 13,305,915 satır
# Kategoriler eklendi
# ✅ Parquet olarak kaydedildi!
#         id                date  client_id  card_id  amount           use_chip  \
# 0  7475327 2010-01-01 00:01:00       1556     2972  -77.00  Swipe Transaction
# 1  7475328 2010-01-01 00:02:00        561     4575   14.57  Swipe Transaction
# 2  7475329 2010-01-01 00:02:00       1129      102   80.00  Swipe Transaction
# 3  7475331 2010-01-01 00:05:00        430     2860  200.00  Swipe Transaction
# 4  7475332 2010-01-01 00:06:00        848     3915   46.41  Swipe Transaction
#
#    merchant_id merchant_city merchant_state    zip   mcc    errors  year  \
# ...
